# %% [markdown]
# ### If running within a Docker, no action is needed. If not, add the installation path (e.g. 'path_to_fwi2d_directory/local/bin') to the environment variables 'PATH' and 'PYTHONPATH' before running the notebook.

# %%
import numpy as np
import math
from scipy import signal
import matplotlib.pyplot as plt
from matplotlib import rcParams

import seppy

sep = seppy.sep()

# Create a directory to store data
# !mkdir -p data
datapath = "./data/"

# %% [markdown]
# ### Generate source time function (Ricker wavelet)

# %%
# source time function parameters
nt=1001 # number of time samples
dt=0.004 # sampling rate (sec)
ot=0.0 # origin time
f0=10. # peak frequency (Hz)
shift=50 # shift wavelet (number of samples)

# source wavelet
w=np.zeros(nt)
pi = math.pi
tshift=shift*dt
sig=math.sqrt(2)/(2*f0*pi)
t=np.linspace(0,(nt-1)*dt,nt)
w=(1.0 - ((t-tshift)/sig)**2)*np.exp( -0.5*((t-tshift)/sig)**2)

plt.plot(np.linspace(ot,(nt-1)*dt,nt),w)
plt.xlabel("Time (sec)")
plt.ylabel("Amplitude")
plt.show()

# %% [markdown]
# ### Generate elastic isotropic models

# %%
nz=201
nx=801
dz=0.01
dx=0.01
oz=0.0
ox=0.0
extent = [ox,ox+(nx-1)*dx,oz+(nz-1)*dz,oz]

# two-layers model (starting model)
model0=np.zeros((3,nx,nz))
model0[0,:,:100] = 2.5 # Vp in km/s
model0[0,:,100:] = 4.0
model0[1,:,:100] = 1.5 # Vs in km/s
model0[1,:,100:] = 2.0
model0[2,:,:100] = 1.0 # Density in g/cc
model0[2,:,100:] = 2.0 # Density in g/cc

# true model = starting model + intrusion
model = np.copy(model0)
model[0,375:426,70:80] = 3.5
model[1,375:426,70:80] = 1.75
model[2,375:426,70:80] = 1.75

plt.figure(figsize=(8,6),dpi=300)
plt.subplot(3,1,1)
plt.imshow(np.transpose(model[0,:,:]),interpolation='none',aspect="auto",extent=extent,cmap='jet',vmin=2.5,vmax=4.0)
plt.xlabel('X (km)')
plt.ylabel('Depth (km)')
plt.colorbar(fraction=0.04, format='%.'+str(1)+'f',label=r'$V_p$ (km/s)')
plt.title("Vp")

plt.subplot(3,1,2)
plt.imshow(np.transpose(model[1,:,:]),interpolation='none',aspect="auto",extent=extent,cmap='jet',vmin=1.5,vmax=2.0)
plt.xlabel('X (km)')
plt.ylabel('Depth (km)')
plt.colorbar(fraction=0.04, format='%.'+str(1)+'f',label=r'$V_s$ (km/s)')
plt.title("Vs")

plt.subplot(3,1,3)
plt.imshow(np.transpose(model[2,:,:]),interpolation='none',aspect="auto",extent=extent,cmap='jet',vmin=1.0,vmax=2.0)
plt.xlabel('X (km)')
plt.ylabel('Depth (km)')
plt.colorbar(fraction=0.04, format='%.'+str(1)+'f',label=r'$\rho$ (g/cc)')
plt.title("Density")

plt.tight_layout()

# %%
# save wavelet and models to SEPlib
sep.write_file(datapath+"wavelet.H", w, ds=np.array([dt]), os=np.array([ot]), dpath=datapath)
sep.write_file(datapath+"model0.H", np.transpose(model0), ds=np.array([dz,dx,1]), os=np.array([oz,ox,0]), dpath=datapath)
sep.write_file(datapath+"model.H", np.transpose(model), ds=np.array([dz,dx,1]), os=np.array([oz,ox,0]), dpath=datapath)

# %% [markdown]
# ### Generate true data and run FWI

# %%
# generate true data
# !WE_MODELING.x source=./data/wavelet.H model=./data/model.H output=./data/data.H datapath=${PWD}/data/ \
verbose=0 fmax=30 dt=-1 mt=0 fangle=1.5708 seismotype=1 \
ns=10 sx0=2 sz0=0.1 sxinc=0.4 nr=401 rx0=2 rz0=0.1 rxinc=0.01 \
bc_top=1 bc_bottom=2 bc_left=2 bc_right=2 taper_top=0 taper_bottom=50 taper_left=50 taper_right=50 taper_strength=0.08
# Out:
# --------------------------------------------------------------------------
# [[16677,1],0]: A high-performance Open MPI point-to-point messaging module
# was unable to find any relevant network interfaces:
#
# Module: OpenFabrics (openib)
#   Host: thanos
#
# Another transport will be used instead, although this may result in
# lower performance.
#
# NOTE: You can disable this warning by setting the MCA parameter
# btl_base_warn_component_unused to 0.
# --------------------------------------------------------------------------
#
# ====================
# Size of MPI communicator = 1 ; current rank = 0
# ====================

# %%
# load, and plot
ns=10 # number of shots
ncomp=2 # number of components
axes_data, data = sep.read_file(datapath+"data.H")
data = data.reshape([axes_data.n[0],int(axes_data.n[1]/(ns)),ns,ncomp],order='F').T

# %%
s=5
d=data[:,s,:,:]
vmax=np.amax(d)
p=0.1

plt.figure(figsize=(8,4),dpi=300)
plt.subplot(1,2,1)
plt.imshow(np.transpose(d[0]),interpolation='sinc',aspect="auto",cmap='Greys',vmax=p*vmax,vmin=-p*vmax)
plt.xlabel('Trace number')
plt.ylabel('Time sample')
plt.title("Shot gather #%s, x-component" %s)

plt.subplot(1,2,2)
plt.imshow(np.transpose(d[1]),interpolation='sinc',aspect="auto",cmap='Greys',vmax=p*vmax,vmin=-p*vmax)
plt.xlabel('Trace number')
plt.ylabel('Time sample')
plt.title("Shot gather #%s, z-component" %s)

plt.tight_layout()
plt.show()

# %%
# run FWI
# !FWI2D.x source=./data/wavelet.H model=./data/model0.H data=./data/data.H output=./data/fwi.H datapath=${PWD}/data/ \
verbose=1 fmax=30 dt=-1 mt=0 fangle=1.5708 seismotype=1 \
ns=10 sx0=2 sz0=0.1 sxinc=0.4 nr=401 rx0=2 rz0=0.1 rxinc=0.01 \
bc_top=1 bc_bottom=2 bc_left=2 bc_right=2 taper_top=0 taper_bottom=50 taper_left=50 taper_right=50 taper_strength=0.08 \
niter=10
# Out:
# --------------------------------------------------------------------------
# [[16545,1],0]: A high-performance Open MPI point-to-point messaging module
# was unable to find any relevant network interfaces:
#
# Module: OpenFabrics (openib)
#   Host: thanos
#
# Another transport will be used instead, although this may result in
# lower performance.
#
# NOTE: You can disable this warning by setting the MCA parameter
# btl_base_warn_component_unused to 0.
# --------------------------------------------------------------------------
#
# ====================
# Size of MPI communicator = 1 ; current rank = 0
# ====================
#
# ====================
# Fri Oct 20 02:41:33 2023
#
# ====================
#
# ==========================
#  Subsurface model geometry
# ==========================
# xmin=0.00000 km, xmax=8.00000 km, dx=0.01000 km, nx=801
# zmin=0.00000 km, zmax=2.00000 km, dz=0.01000 km, nz=201
#
# ==========================
#  Boundary conditions
# ==========================
# Top boundary condition = free surface	 taper size = 0	 taper type = none
# Bottom boundary condition = locally absorbing	 taper size = 50	 taper type = cosine squared
# Left boundary condition = locally absorbing	 taper size = 50	 taper type = cosine squared
# Right boundary condition = locally absorbing	 taper size = 50	 taper type = cosine squared
#
# ==========================
#  Sources' and receivers' geometry
# ==========================
# Sources' and receivers' coordinates are read from parameters list
# Receivers are point measurement of type particle velocity
# Number of sources = 10
# Shot 0 located at x=2.00000 km, z=0.10000 km, has 401 receivers
# Shot 1 located at x=2.40000 km, z=0.10000 km, has 401 receivers
# Shot 2 located at x=2.80000 km, z=0.10000 km, has 401 receivers
# Shot 3 located at x=3.20000 km, z=0.10000 km, has 401 receivers
# Shot 4 located at x=3.60000 km, z=0.10000 km, has 401 receivers
# Shot 5 located at x=4.00000 km, z=0.10000 km, has 401 receivers
# Shot 6 located at x=4.40000 km, z=0.10000 km, has 401 receivers
# Shot 7 located at x=4.80000 km, z=0.10000 km, has 401 receivers
# Shot 8 located at x=5.20000 km, z=0.10000 km, has 401 receivers
# Shot 9 located at x=5.60000 km, z=0.10000 km, has 401 receivers
# Total number of 2-components receivers to be modeled = 4010
#
# ==========================
#  Source wavelet
# ==========================
# Vector force is assumed with an angle of 1.570800 rad clockwise wrt to the horizontal
# Input wavelet will be duplicated 2 x 10 times with the appropriate scaling
# Parameters mxx, mzz, mxz are ignored
#
# ==========================
#  Inversion parameters
# ==========================
# Non-linear solver = lbfgs
# Line search = regular_wolfe
# Number of iterations = 10
# Maximum number of trials per iteration = 10
# Threshold to stop the inversion = 0.000000
# The model parameterization used in the elastic inversion is Vp, Vs, rho, aniso
# No regularization will be used
# If "ioutput" is provided, the model, gradient, and residual will be saved every 10 iterations
# #########################################################################
# Iteration = 0; functional = 16.598963; normalized functional = 1
# #########################################################################
# ==============================
# Trial = 1
# Step length = 0.125114
# Function value = 11.779595
# Gradient norm = 4.895442
# ==============================
# Found a satisfactory step length
# ==============================
# #########################################################################
# Iteration = 1; functional = 11.779595; normalized functional = 0.709659
# #########################################################################
# ==============================
# Trial = 1
# Step length = 2.666843
# Function value = 10.589397
# Gradient norm = 11.487027
# ==============================
# Found a satisfactory step length
# ==============================
# #########################################################################
# Iteration = 2; functional = 10.589397; normalized functional = 0.637955
# #########################################################################
# ==============================
# Trial = 1
# Step length = 1.489211
# Function value = 7.140383
# Gradient norm = 4.773777
# ==============================
# Found a satisfactory step length
# ==============================
# #########################################################################
# Iteration = 3; functional = 7.140383; normalized functional = 0.430170
# #########################################################################
# ==============================
# Trial = 1
# Step length = 8.323133
# Function value = 17.040951
# Last gradient norm = 4.773777
# ==============================
# Trial = 2
# Step length = 1.858919
# Function value = 6.211187
# Gradient norm = 2.811370
# ==============================
# Found a satisfactory step length
# ==============================
# #########################################################################
# Iteration = 4; functional = 6.211187; normalized functional = 0.374191
# #########################################################################
# ==============================
# Trial = 1
# Step length = 3.588009
# Function value = 5.269199
# Gradient norm = 2.431798
# ==============================
# Found a satisfactory step length
# ==============================
# #########################################################################
# Iteration = 5; functional = 5.269199; normalized functional = 0.317441
# #########################################################################
# ==============================
# Trial = 1
# Step length = 1.525701
# Function value = 4.540046
# Gradient norm = 2.579002
# ==============================
# Found a satisfactory step length
# ==============================
# #########################################################################
# Iteration = 6; functional = 4.540046; normalized functional = 0.273514
# #########################################################################
# ==============================
# Trial = 1
# Step length = 1.611089
# Function value = 4.353827
# Gradient norm = 4.268553
# ==============================
# Found a satisfactory step length
# ==============================
# #########################################################################
# Iteration = 7; functional = 4.353827; normalized functional = 0.262295
# #########################################################################
# ==============================
# Trial = 1
# Step length = 1.573950
# Function value = 3.699440
# Gradient norm = 1.511143
# ==============================
# Found a satisfactory step length
# ==============================
# #########################################################################
# Iteration = 8; functional = 3.699440; normalized functional = 0.222872
# #########################################################################
# ==============================
# Trial = 1
# Step length = 6.466815
# Function value = 4.293114
# Last gradient norm = 1.511143
# ==============================
# Trial = 2
# Step length = 2.426447
# Function value = 3.358502
# Gradient norm = 1.615726
# ==============================
# Found a satisfactory step length
# ==============================
# #########################################################################
# Iteration = 9; functional = 3.358502; normalized functional = 0.202332
# #########################################################################
# ==============================
# Trial = 1
# Step length = 2.385426
# Function value = 2.943727
# Gradient norm = 1.087129
# ==============================
# Found a satisfactory step length
# ==============================
# #########################################################################
# Iteration = 10; functional = 2.943727; normalized functional = 0.177344
# #########################################################################
#
# ==============================
# Total number of l-BFGS iterations: 10
# Total number of function evaluations: 13
# Total number of gradient evaluations: 11
# ==============================
#
#
# ====================
# Fri Oct 20 03:06:14 2023
#
# ====================

# %%
# load FWI model and plot
axes, fwi = sep.read_file(datapath+"fwi.H")
fwi = fwi.reshape(axes.n,order='F').T

# %%
plt.figure(figsize=(8,6),dpi=300)
plt.subplot(3,1,1)
plt.imshow(np.transpose(fwi[0,:,:]),interpolation='none',aspect="auto",extent=extent,cmap='jet',vmin=2.5,vmax=4.0)
plt.xlabel('X (km)')
plt.ylabel('Depth (km)')
plt.colorbar(fraction=0.04, format='%.'+str(1)+'f',label=r'$V_p$ (km/s)')
plt.title("Vp")

plt.subplot(3,1,2)
plt.imshow(np.transpose(fwi[1,:,:]),interpolation='none',aspect="auto",extent=extent,cmap='jet',vmin=1.5,vmax=2.0)
plt.xlabel('X (km)')
plt.ylabel('Depth (km)')
plt.colorbar(fraction=0.04, format='%.'+str(1)+'f',label=r'$V_s$ (km/s)')
plt.title("Vs")

plt.subplot(3,1,3)
plt.imshow(np.transpose(fwi[2,:,:]),interpolation='none',aspect="auto",extent=extent,cmap='jet',vmin=1.0,vmax=2.0)
plt.xlabel('X (km)')
plt.ylabel('Depth (km)')
plt.colorbar(fraction=0.04, format='%.'+str(1)+'f',label=r'$\rho$ (g/cc)')
plt.title("Density")

plt.tight_layout()

# %% [markdown]
# Clean up the data directory

# %%
# !rm -rf data
